# %%
import pandas as pd

# Inspect Karavolias 2023 Table S1 & S2
df_s1 = pd.read_excel('papers/k23values/useTAbleS1.xlsx')
df_s2 = pd.read_excel('papers/k23values/thisis tableS2.xlsx')

print("--- Table S1 Columns & First 3 Rows ---")
print(df_s1.info())
print(df_s1.head(3))

print("\n--- Table S2 Columns & First 3 Rows ---")
print(df_s2.info())
print(df_s2.head(3))
# Out:
# --- Table S1 Columns & First 3 Rows ---
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 20 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   Supplemental Table S1. List of the species used for comparative analyses and copy number variations of the STOMAGEN family  27 non-null     str
#  1   Unnamed: 1                                                                                                                  23 non-null     str
#  2   Unnamed: 2                                                                                                                  0 non-null      float64
# ...

# %%
import pandas as pd

# Inspect Karavolias 2023 Table S1 & S2
df_s1 = pd.read_excel('papers/k23values/useTAbleS1.xlsx')
df_s2 = pd.read_excel('papers/k23values/thisis tableS2.xlsx')

print("--- Table S1 Columns & First 3 Rows ---")
print(df_s1.info())
print(df_s1.head(3))

print("\n--- Table S2 Columns & First 3 Rows ---")
print(df_s2.info())
print(df_s2.head(3))
# Out:
# --- Table S1 Columns & First 3 Rows ---
# <class 'pandas.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 20 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   Supplemental Table S1. List of the species used for comparative analyses and copy number variations of the STOMAGEN family  27 non-null     str
#  1   Unnamed: 1                                                                                                                  23 non-null     str
#  2   Unnamed: 2                                                                                                                  0 non-null      float64
# ...
